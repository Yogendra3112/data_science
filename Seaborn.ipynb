# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

# %%
pd.read_csv(r'C:\Users\Yogi\Downloads\Salaries.csv')
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# ..        ...        ...   ...      ...     ...       ...
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0
#
# [78 rows x 6 columns]

# %%
a=pd.read_csv(r'C:\Users\Yogi\Downloads\Salaries.csv')
sns.relplot(x='rank',y='service',data=a)

# %%
a=pd.read_csv(r'C:\Users\Yogi\Downloads\Salaries.csv')
sns.relplot(x='rank',y='service',hue='sex',data=a,kind='line')

# %%
a=pd.read_csv(r'C:\Users\Yogi\Downloads\Salaries.csv')
sns.relplot(x='rank',y='service',data=a,kind='line')

# %%
a=pd.read_csv(r'C:\Users\Yogi\Downloads\Salaries.csv')
sns.catplot(x='rank',y='service',hue='',data=a,kind='violin')

# %%
c=np.random.normal(0,10,100)
sns.distplot(c)

# %%
x=np.random.normal(0,10,100)
y=np.random.normal(0,10,100)
sns.jointplot(x=x,y=y,color='r',kind='kde')

# %%
a=pd.read_csv(r'C:\Users\Yogi\Downloads\Salaries.csv')
b=sns.FacetGrid(a, col='rank')
b.map(plt.hist,'service')

# %%
a=pd.read_csv(r'C:\Users\Yogi\Downloads\Salaries.csv')
sns.PairGrid(a)
# b.map(plt.hist)

# %%
sns.set(style='darkgrid')
c=np.random.normal(0,10,100)
sns.distplot(c)

# %%
sns.set(style='white',color_codes=True)
c=np.random.normal(0,10,100)
sns.distplot(c)
sns.despine(offset=10, trim=True)

# %%
s=sns.color_palette()
sns.palplot(s)

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.catplot('species','petal_length',data=df,kind='boxen')

# %%
sns.catplot('species','petal_length',data=df,kind='box')

# %%
sns.set(style='darkgrid')
sns.catplot('species','petal_length',data=df,kind='violin')

# %%
sns.catplot(y='species',x='petal_length',data=df,kind='violin')

# %%
sns.regplot('petal_width','petal_length',data=df,color='g')

# %%
sns.regplot('petal_width','petal_length',data=df,color='g',x_estimator=np.mean)

# %%
sns.lmplot('petal_width','petal_length',data=df,hue='species',x_jitter=1)

# %%
sns.lmplot('petal_width','petal_length',data=df,hue='species')

# %%
sns.lmplot('petal_width','petal_length',data=df,hue='species',x_estimator=np.mean)

# %%
sns.lmplot('petal_width','petal_length',data=df,hue='species',x_estimator=np.median)

# %%
sns.jointplot('petal_width','petal_length',data=df,color='r',kind='kde')

# %%
sns.pairplot(df)

# %%
g=sns.PairGrid(df)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot,n_levels=10)

# %%
sns.lmplot(x='sepal_length',y='sepal_length',data=df.query("species=='setosa'"),ci=None,scatter_kws={'s':80})

# %%
sns.lmplot('petal_width','petal_length',data=df.query("species=='setosa'"),x_estimator=np.mean)

# %%
sns.lmplot('petal_width','petal_length',data=df.query("species=='setosa'"),x_estimator=np.mean,ci=None)

# %%
sns.lmplot('petal_width','petal_length',data=df.query("species=='setosa'"),x_estimator=np.mean,ci=None,robust=True,markers='*')

# %%
sns.set(style='darkgrid')
sns.lmplot('petal_width','petal_length',data=df,x_estimator=np.mean,col='species')

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
