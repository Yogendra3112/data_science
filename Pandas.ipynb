# %%
print('Welcome to Pandas  !!!')
# Out:
# Welcome to Pandas  !!!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## To read file in your system

# %%
df = pd.read_csv(r'C:\Users\Yogi\Downloads\Salaries.csv')
df
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# ..        ...        ...   ...      ...     ...       ...
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0
#
# [78 rows x 6 columns]

# %% [markdown]
# ## To read an online data file

# %%
df = pd.read_csv("https://bitbucket.org/ntpl_sylvester/dataset/raw/467616310ddfaf8abbbbc13bdf1e32cdf0842cbd/Salaries.csv")
df
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# ..        ...        ...   ...      ...     ...       ...
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0
#
# [78 rows x 6 columns]

# %%
df.describe()
# Out:
#              phd    service         salary
# count  76.000000  78.000000      76.000000
# mean   19.605263  15.051282  108003.355263
# std    12.508215  12.139768   28525.350088
# min     1.000000   0.000000   57800.000000
# 25%    10.000000   5.250000   87250.000000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.250000  20.750000  127077.750000
# max    56.000000  51.000000  186960.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
# rank          78 non-null object
# discipline    78 non-null object
# phd           76 non-null float64
# service       78 non-null int64
# sex           78 non-null object
# salary        76 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.8+ KB

# %%
df.ndim                                            # gives dimentions of data
# Out:
# 2

# %%
df.shape
# Out:
# (78, 6)

# %%
df.size
# Out:
# 468

# %%
df.head()
# Out:
#    rank discipline   phd  service   sex    salary
# 0  Prof          B  56.0       49  Male  186960.0
# 1  Prof          A  12.0        6  Male   93000.0
# 2  Prof          A  23.0       20  Male  110515.0
# 3  Prof          A  40.0       31  Male  131205.0
# 4  Prof          B  20.0       18  Male  104800.0

# %%
df.head(10)
# Out:
#         rank discipline   phd  service   sex    salary
# 0       Prof          B  56.0       49  Male  186960.0
# 1       Prof          A  12.0        6  Male   93000.0
# 2       Prof          A  23.0       20  Male  110515.0
# 3       Prof          A  40.0       31  Male  131205.0
# 4       Prof          B  20.0       18  Male  104800.0
# 5       Prof          A  20.0       20  Male  122400.0
# 6  AssocProf          A  20.0       17  Male   81285.0
# 7       Prof          A  18.0       18  Male       NaN
# 8       Prof          A  29.0       19  Male   94350.0
# 9       Prof          A  51.0       51  Male   57800.0

# %%
df.tail()
# Out:
#          rank discipline   phd  service     sex    salary
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0

# %%
df.tail(10)
# Out:
#          rank discipline   phd  service     sex    salary
# 68   AsstProf          A   4.0        2  Female   77500.0
# 69       Prof          A  28.0        7  Female  116450.0
# 70   AsstProf          A   8.0        3  Female   78500.0
# 71  AssocProf          B  12.0        9  Female   71065.0
# 72       Prof          B  24.0       15  Female  161101.0
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0

# %%
df.sample(10)
# Out:
#          rank discipline   phd  service     sex    salary
# 64  AssocProf          A  26.0       24  Female   73300.0
# 4        Prof          B  20.0       18    Male  104800.0
# 33       Prof          B  18.0       18    Male  120000.0
# 7        Prof          A  18.0       18    Male       NaN
# 23   AsstProf          A   2.0        0    Male   85000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 5        Prof          A  20.0       20    Male  122400.0
# 9        Prof          A  51.0       51    Male   57800.0
# 51       Prof          B  20.0       14  Female  127512.0
# 65       Prof          A  36.0       19  Female  117555.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=78, step=1)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes
# Out:
# rank           object
# discipline     object
# phd           float64
# service         int64
# sex            object
# salary        float64
# dtype: object

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.values
# Out:
# array([['Prof', 'B', 56.0, 49, 'Male', 186960.0],
#        ['Prof', 'A', 12.0, 6, 'Male', 93000.0],
#        ['Prof', 'A', 23.0, 20, 'Male', 110515.0],
#        ['Prof', 'A', 40.0, 31, 'Male', 131205.0],
#        ['Prof', 'B', 20.0, 18, 'Male', 104800.0],
#        ['Prof', 'A', 20.0, 20, 'Male', 122400.0],
#        ['AssocProf', 'A', 20.0, 17, 'Male', 81285.0],
#        ['Prof', 'A', 18.0, 18, 'Male', nan],
#        ['Prof', 'A', 29.0, 19, 'Male', 94350.0],
#        ['Prof', 'A', 51.0, 51, 'Male', 57800.0],
#        ['Prof', 'B', 39.0, 33, 'Male', 128250.0],
#        ['Prof', 'B', 23.0, 23, 'Male', 134778.0],
#        ['AsstProf', 'B', 1.0, 0, 'Male', 88000.0],
#        ['Prof', 'B', nan, 33, 'Male', 162200.0],
#        ['Prof', 'B', 25.0, 19, 'Male', 153750.0],
#        ['Prof', 'B', 17.0, 3, 'Male', 150480.0],
#        ['AsstProf', 'B', 8.0, 3, 'Male', 75044.0],
#        ['AsstProf', 'B', 4.0, 0, 'Male', 92000.0],
#        ['Prof', 'A', 19.0, 7, 'Male', 107300.0],
# ...

# %%
df.describe()                                       # gives only numeric data
# Out:
#              phd    service         salary
# count  76.000000  78.000000      76.000000
# mean   19.605263  15.051282  108003.355263
# std    12.508215  12.139768   28525.350088
# min     1.000000   0.000000   57800.000000
# 25%    10.000000   5.250000   87250.000000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.250000  20.750000  127077.750000
# max    56.000000  51.000000  186960.000000

# %%
df.describe(include=['object', 'float64', 'int64', 'bool'])  # will give non numeric data also
# Out:
#         rank discipline        phd    service     sex         salary
# count     78         78  76.000000  78.000000      78      76.000000
# unique     3          2        NaN        NaN       2            NaN
# top     Prof          B        NaN        NaN  Female            NaN
# freq      46         42        NaN        NaN      39            NaN
# mean     NaN        NaN  19.605263  15.051282     NaN  108003.355263
# std      NaN        NaN  12.508215  12.139768     NaN   28525.350088
# min      NaN        NaN   1.000000   0.000000     NaN   57800.000000
# 25%      NaN        NaN  10.000000   5.250000     NaN   87250.000000
# 50%      NaN        NaN  18.500000  14.500000     NaN  104671.000000
# 75%      NaN        NaN  27.250000  20.750000     NaN  127077.750000
# max      NaN        NaN  56.000000  51.000000     NaN  186960.000000

# %%
df.max()                                         # max of all features
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()                                         # min of all features
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean()
# Out:
# phd            19.605263
# service        15.051282
# salary     108003.355263
# dtype: float64

# %%
df.mode()
# Out:
#    rank discipline  phd  service     sex   salary
# 0  Prof          B  4.0      3.0  Female  92000.0
# 1   NaN        NaN  NaN      NaN    Male      NaN

# %%
df.median()
# Out:
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
df.std()                                               # gives std of numeric data
# Out:
# phd           12.508215
# service       12.139768
# salary     28525.350088
# dtype: float64

# %%
df.head(50).mean()                                    # mean of first 50 records
# Out:
# phd            21.437500
# service        17.600000
# salary     113997.020833
# dtype: float64

# %%
df.sample(10)                                        # gives random records  for given number
# Out:
#          rank discipline   phd  service     sex    salary
# 74  AssocProf          B  19.0        6  Female  104542.0
# 38   AsstProf          B   4.0        3    Male   91000.0
# 63       Prof          A  29.0       27  Female   91000.0
# 35       Prof          B  28.0       23    Male  126933.0
# 9        Prof          A  51.0       51    Male   57800.0
# 4        Prof          B  20.0       18    Male  104800.0
# 22   AsstProf          A   4.0        2    Male   73000.0
# 42   AsstProf          B   4.0        2  Female   80225.0
# 72       Prof          B  24.0       15  Female  161101.0
# 45       Prof          B  25.0       25  Female  140096.0

# %%
df.loc[10:50]                                       # gives only desired rows
# Out:
#          rank discipline   phd  service     sex    salary
# 10       Prof          B  39.0       33    Male  128250.0
# 11       Prof          B  23.0       23    Male  134778.0
# 12   AsstProf          B   1.0        0    Male   88000.0
# 13       Prof          B   NaN       33    Male  162200.0
# 14       Prof          B  25.0       19    Male  153750.0
# 15       Prof          B  17.0        3    Male  150480.0
# 16   AsstProf          B   8.0        3    Male   75044.0
# 17   AsstProf          B   4.0        0    Male   92000.0
# 18       Prof          A  19.0        7    Male  107300.0
# 19       Prof          A  29.0       27    Male  150500.0
# 20   AsstProf          B   4.0        4    Male   92000.0
# 21       Prof          A  33.0       30    Male  103106.0
# 22   AsstProf          A   4.0        2    Male   73000.0
# 23   AsstProf          A   2.0        0    Male   85000.0
# 24       Prof          A  30.0       23    Male   91100.0
# ...

# %%
df.loc[10:30,['rank','salary']]                           # specific rows with specific columns
# Out:
#          rank    salary
# 10       Prof  128250.0
# 11       Prof  134778.0
# 12   AsstProf   88000.0
# 13       Prof  162200.0
# 14       Prof  153750.0
# 15       Prof  150480.0
# 16   AsstProf   75044.0
# 17   AsstProf   92000.0
# 18       Prof  107300.0
# 19       Prof  150500.0
# 20   AsstProf   92000.0
# 21       Prof  103106.0
# 22   AsstProf   73000.0
# 23   AsstProf   85000.0
# 24       Prof   91100.0
# 25       Prof   99418.0
# 26       Prof  148750.0
# 27       Prof  155865.0
# 28   AsstProf       NaN
# 29       Prof  123683.0
# 30  AssocProf  107008.0

# %%
df.iloc[10:20, 2:5]                                   # 10 -19 rows and 2-5 columns
# Out:
#      phd  service   sex
# 10  39.0       33  Male
# 11  23.0       23  Male
# 12   1.0        0  Male
# 13   NaN       33  Male
# 14  25.0       19  Male
# 15  17.0        3  Male
# 16   8.0        3  Male
# 17   4.0        0  Male
# 18  19.0        7  Male
# 19  29.0       27  Male

# %%
df.iloc[[2,4,6,9], [2,3,4,1]]
# Out:
#     phd  service   sex discipline
# 2  23.0       20  Male          A
# 4  20.0       18  Male          B
# 6  20.0       17  Male          A
# 9  51.0       51  Male          A

# %%
df['rank'].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
list1 = df['rank'].unique().tolist()
print(list1)
# Out:
# ['Prof', 'AssocProf', 'AsstProf']

# %%
df[['rank','salary']][df['sex']=='Female']                    # gives rank where sex is female
# Out:
#          rank    salary
# 39       Prof  129000.0
# 40       Prof  137000.0
# 41  AssocProf   74830.0
# 42   AsstProf   80225.0
# 43   AsstProf   77000.0
# 44       Prof  151768.0
# 45       Prof  140096.0
# 46   AsstProf   74692.0
# 47  AssocProf  103613.0
# 48       Prof  111512.0
# 49       Prof  122960.0
# 50   AsstProf   97032.0
# 51       Prof  127512.0
# 52       Prof  105000.0
# 53   AsstProf   73500.0
# 54  AssocProf   62884.0
# 55   AsstProf   72500.0
# 56  AssocProf   77500.0
# 57   AsstProf   72500.0
# 58       Prof  144651.0
# 59  AssocProf  103994.0
# 60   AsstProf   92000.0
# 61  AssocProf  103750.0
# 62  AssocProf  109650.0
# 63       Prof   91000.0
# 64  AssocProf   73300.0
# 65       Prof  117555.0
# 66   AsstProf   63100.0
# 67       Prof   90450.0
# 68   AsstProf   77500.0
# 69       Prof  116450.0
# 70   AsstProf   78500.0
# 71  AssocProf   71065.0
# 72       Prof  161101.0
# 73       Prof  105450.0
# 74  AssocProf  104542.0
# 75       Prof  124312.0
# ...

# %%
(df['rank'][df['sex']=='Female']).value_counts()            # gives no. of female as per rank
# Out:
# Prof         18
# AsstProf     11
# AssocProf    10
# Name: rank, dtype: int64

# %%
df[(df['sex']=='Female') & (df['rank']=='Prof')]              # gives true and false
# Out:
#     rank discipline   phd  service     sex    salary
# 39  Prof          B  18.0       18  Female  129000.0
# 40  Prof          A  39.0       36  Female  137000.0
# 44  Prof          B  23.0       19  Female  151768.0
# 45  Prof          B  25.0       25  Female  140096.0
# 48  Prof          B  17.0       17  Female  111512.0
# 49  Prof          B  17.0       18  Female  122960.0
# 51  Prof          B  20.0       14  Female  127512.0
# 52  Prof          A  12.0        0  Female  105000.0
# 58  Prof          B  36.0       26  Female  144651.0
# 63  Prof          A  29.0       27  Female   91000.0
# 65  Prof          A  36.0       19  Female  117555.0
# 67  Prof          A  17.0       11  Female   90450.0
# 69  Prof          A  28.0        7  Female  116450.0
# 72  Prof          B  24.0       15  Female  161101.0
# 73  Prof          B  18.0       10  Female  105450.0
# 75  Prof          B  17.0       17  Female  124312.0
# 76  Prof          A  28.0       14  Female  109954.0
# ...

# %%
df[(df['sex']=='Female') & (df['rank']=='Prof')]           # gives only female prof
# Out:
#     rank discipline   phd  service     sex    salary
# 39  Prof          B  18.0       18  Female  129000.0
# 40  Prof          A  39.0       36  Female  137000.0
# 44  Prof          B  23.0       19  Female  151768.0
# 45  Prof          B  25.0       25  Female  140096.0
# 48  Prof          B  17.0       17  Female  111512.0
# 49  Prof          B  17.0       18  Female  122960.0
# 51  Prof          B  20.0       14  Female  127512.0
# 52  Prof          A  12.0        0  Female  105000.0
# 58  Prof          B  36.0       26  Female  144651.0
# 63  Prof          A  29.0       27  Female   91000.0
# 65  Prof          A  36.0       19  Female  117555.0
# 67  Prof          A  17.0       11  Female   90450.0
# 69  Prof          A  28.0        7  Female  116450.0
# 72  Prof          B  24.0       15  Female  161101.0
# 73  Prof          B  18.0       10  Female  105450.0
# 75  Prof          B  17.0       17  Female  124312.0
# 76  Prof          A  28.0       14  Female  109954.0
# ...

# %%
c = (df['sex'][df['rank']=='Prof']).value_counts(normalize=True)*100      # gives % of male and female when rank is Prof              
print(c)
# Out:
# Male      60.869565
# Female    39.130435
# Name: sex, dtype: float64

# %%
(df['salary']).value_counts(dropna=False)                                 # gives salary count including NaN
# Out:
# 92000.0     3
# 72500.0     2
# NaN         2
# 77500.0     2
# 91000.0     2
#            ..
# 103994.0    1
# 107300.0    1
# 120000.0    1
# 140096.0    1
# 104800.0    1
# Name: salary, Length: 72, dtype: int64

# %%
(df['salary']).value_counts(dropna=True)                              # without NaN
# Out:
# 92000.0     3
# 77500.0     2
# 72500.0     2
# 91000.0     2
# 117555.0    1
#            ..
# 103994.0    1
# 107300.0    1
# 140096.0    1
# 88000.0     1
# 104800.0    1
# Name: salary, Length: 71, dtype: int64

# %%
((df['rank']).value_counts())                                       # rank wise destribution
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df['salary'].describe()                                            # description of perticolar column salary
# Out:
# count        76.000000
# mean     108003.355263
# std       28525.350088
# min       57800.000000
# 25%       87250.000000
# 50%      104671.000000
# 75%      127077.750000
# max      186960.000000
# Name: salary, dtype: float64

# %%
df['salary'].isnull()                                           # gives true and false
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Name: salary, Length: 78, dtype: bool

# %%
df[df['salary'].isnull()]                                     # it gives data frame using boolian indexing
# Out:
#         rank discipline   phd  service   sex  salary
# 7       Prof          A  18.0       18  Male     NaN
# 28  AsstProf          B   7.0        2  Male     NaN

# %%
grp1 = df.groupby(['sex','rank'])
for i in grp1:
    print(i)
    print('\n \n ')
# Out:
# (('Female', 'AssocProf'),          rank discipline   phd  service     sex    salary
# 41  AssocProf          A  13.0        8  Female   74830.0
# 47  AssocProf          B  11.0       11  Female  103613.0
# 54  AssocProf          A  25.0       22  Female   62884.0
# 56  AssocProf          A  10.0        8  Female   77500.0
# 59  AssocProf          B  12.0       10  Female  103994.0
# 61  AssocProf          B  13.0       10  Female  103750.0
# 62  AssocProf          B  14.0        7  Female  109650.0
# 64  AssocProf          A  26.0       24  Female   73300.0
# 71  AssocProf          B  12.0        9  Female   71065.0
# 74  AssocProf          B  19.0        6  Female  104542.0)
#
#
#
# (('Female', 'AsstProf'),         rank discipline   phd  service     sex   salary
# 42  AsstProf          B   4.0        2  Female  80225.0
# 43  AsstProf          B   5.0        0  Female  77000.0
# 46  AsstProf          B  11.0        3  Female  74692.0
# ...

# %%
df.groupby(['sex','rank']).mean()
# Out:
#                         phd    service         salary
# sex    rank
# Female AssocProf  15.500000  11.500000   88512.800000
#        AsstProf    5.636364   2.545455   78049.909091
#        Prof       23.722222  17.111111  121967.611111
# Male   AssocProf  14.500000  10.666667  102697.666667
#        AsstProf    4.250000   1.750000   85149.142857
#        Prof       29.000000  24.178571  124630.518519

# %%
df.groupby(['sex','rank']).min()
# Out:
#                  discipline   phd  service   salary
# sex    rank
# Female AssocProf          A  10.0        6  62884.0
#        AsstProf           A   2.0        0  63100.0
#        Prof               A  12.0        0  90450.0
# Male   AssocProf          A   9.0        7  81285.0
#        AsstProf           A   1.0        0  73000.0
#        Prof               A  12.0        3  57800.0

# %%
df.groupby(['sex','rank']).max()
# Out:
#                  discipline   phd  service    salary
# sex    rank
# Female AssocProf          B  26.0       24  109650.0
#        AsstProf           B  11.0        6   97032.0
#        Prof               B  39.0       36  161101.0
# Male   AssocProf          B  20.0       17  119800.0
#        AsstProf           B   8.0        4   92000.0
#        Prof               B  56.0       51  186960.0

# %%
c= df.groupby('rank')
for i in c:
    print(i)
# Out:
# ('AssocProf',          rank discipline   phd  service     sex    salary
# 6   AssocProf          A  20.0       17    Male   81285.0
# 30  AssocProf          B   9.0        7    Male  107008.0
# 34  AssocProf          B   NaN        8    Male  119800.0
# 41  AssocProf          A  13.0        8  Female   74830.0
# 47  AssocProf          B  11.0       11  Female  103613.0
# 54  AssocProf          A  25.0       22  Female   62884.0
# 56  AssocProf          A  10.0        8  Female   77500.0
# 59  AssocProf          B  12.0       10  Female  103994.0
# 61  AssocProf          B  13.0       10  Female  103750.0
# 62  AssocProf          B  14.0        7  Female  109650.0
# 64  AssocProf          A  26.0       24  Female   73300.0
# 71  AssocProf          B  12.0        9  Female   71065.0
# 74  AssocProf          B  19.0        6  Female  104542.0)
# ('AsstProf',         rank discipline   phd  service     sex   salary
# 12  AsstProf          B   1.0        0    Male  88000.0
# ...

# %%
grp2 = df.groupby(['rank','sex','discipline'])
for i in grp2:
    print(i)
# Out:
# (('AssocProf', 'Female', 'A'),          rank discipline   phd  service     sex   salary
# 41  AssocProf          A  13.0        8  Female  74830.0
# 54  AssocProf          A  25.0       22  Female  62884.0
# 56  AssocProf          A  10.0        8  Female  77500.0
# 64  AssocProf          A  26.0       24  Female  73300.0)
# (('AssocProf', 'Female', 'B'),          rank discipline   phd  service     sex    salary
# 47  AssocProf          B  11.0       11  Female  103613.0
# 59  AssocProf          B  12.0       10  Female  103994.0
# 61  AssocProf          B  13.0       10  Female  103750.0
# 62  AssocProf          B  14.0        7  Female  109650.0
# 71  AssocProf          B  12.0        9  Female   71065.0
# 74  AssocProf          B  19.0        6  Female  104542.0)
# (('AssocProf', 'Male', 'A'),         rank discipline   phd  service   sex   salary
# 6  AssocProf          A  20.0       17  Male  81285.0)
# ...

# %%
 df.groupby(['rank','sex','discipline']).median()
# Out:
#                               phd  service    salary
# rank      sex    discipline
# AssocProf Female A           19.0     15.0   74065.0
#                  B           12.5      9.5  103872.0
#           Male   A           20.0     17.0   81285.0
#                  B            9.0      7.5  113404.0
# AsstProf  Female A            4.5      2.5   73000.0
#                  B            5.0      3.0   80225.0
#           Male   A            3.0      1.0   79000.0
#                  B            4.0      2.5   91000.0
# Prof      Female A           28.0     14.5  109800.0
#                  B           19.0     17.5  128256.0
#           Male   A           29.0     20.0  105287.5
#                  B           24.0     23.0  134778.0

# %%
df[df['salary']>=100000]
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# 5        Prof          A  20.0       20    Male  122400.0
# 10       Prof          B  39.0       33    Male  128250.0
# 11       Prof          B  23.0       23    Male  134778.0
# 13       Prof          B   NaN       33    Male  162200.0
# 14       Prof          B  25.0       19    Male  153750.0
# 15       Prof          B  17.0        3    Male  150480.0
# 18       Prof          A  19.0        7    Male  107300.0
# 19       Prof          A  29.0       27    Male  150500.0
# 21       Prof          A  33.0       30    Male  103106.0
# 26       Prof          A  38.0       19    Male  148750.0
# 27       Prof          A  45.0       43    Male  155865.0
# ...

# %%
df1= df[df['salary']>=100000]
df1['rank'].unique()
# Out:
# array(['Prof', 'AssocProf'], dtype=object)

# %%
df[['salary','sex']][df['sex'] == 'Female' ]
# Out:
#       salary     sex
# 39  129000.0  Female
# 40  137000.0  Female
# 41   74830.0  Female
# 42   80225.0  Female
# 43   77000.0  Female
# 44  151768.0  Female
# 45  140096.0  Female
# 46   74692.0  Female
# 47  103613.0  Female
# 48  111512.0  Female
# 49  122960.0  Female
# 50   97032.0  Female
# 51  127512.0  Female
# 52  105000.0  Female
# 53   73500.0  Female
# 54   62884.0  Female
# 55   72500.0  Female
# 56   77500.0  Female
# 57   72500.0  Female
# 58  144651.0  Female
# 59  103994.0  Female
# 60   92000.0  Female
# 61  103750.0  Female
# 62  109650.0  Female
# 63   91000.0  Female
# 64   73300.0  Female
# 65  117555.0  Female
# 66   63100.0  Female
# 67   90450.0  Female
# 68   77500.0  Female
# 69  116450.0  Female
# 70   78500.0  Female
# 71   71065.0  Female
# 72  161101.0  Female
# 73  105450.0  Female
# 74  104542.0  Female
# 75  124312.0  Female
# 76  109954.0  Female
# 77  109646.0  Female

# %%
df[df['sex'] == 'Female' ][['salary','sex']]
# Out:
#       salary     sex
# 39  129000.0  Female
# 40  137000.0  Female
# 41   74830.0  Female
# 42   80225.0  Female
# 43   77000.0  Female
# 44  151768.0  Female
# 45  140096.0  Female
# 46   74692.0  Female
# 47  103613.0  Female
# 48  111512.0  Female
# 49  122960.0  Female
# 50   97032.0  Female
# 51  127512.0  Female
# 52  105000.0  Female
# 53   73500.0  Female
# 54   62884.0  Female
# 55   72500.0  Female
# 56   77500.0  Female
# 57   72500.0  Female
# 58  144651.0  Female
# 59  103994.0  Female
# 60   92000.0  Female
# 61  103750.0  Female
# 62  109650.0  Female
# 63   91000.0  Female
# 64   73300.0  Female
# 65  117555.0  Female
# 66   63100.0  Female
# 67   90450.0  Female
# 68   77500.0  Female
# 69  116450.0  Female
# 70   78500.0  Female
# 71   71065.0  Female
# 72  161101.0  Female
# 73  105450.0  Female
# 74  104542.0  Female
# 75  124312.0  Female
# 76  109954.0  Female
# 77  109646.0  Female

# %% [markdown]
# ## Sorting of columns

# %%
df.sort_values(by='salary')
# Out:
#          rank discipline   phd  service     sex    salary
# 9        Prof          A  51.0       51    Male   57800.0
# 54  AssocProf          A  25.0       22  Female   62884.0
# 66   AsstProf          A   7.0        6  Female   63100.0
# 71  AssocProf          B  12.0        9  Female   71065.0
# 57   AsstProf          A   3.0        1  Female   72500.0
# ..        ...        ...   ...      ...     ...       ...
# 72       Prof          B  24.0       15  Female  161101.0
# 13       Prof          B   NaN       33    Male  162200.0
# 0        Prof          B  56.0       49    Male  186960.0
# 7        Prof          A  18.0       18    Male       NaN
# 28   AsstProf          B   7.0        2    Male       NaN
#
# [78 rows x 6 columns]

# %%
df.sort_values(by=['salary'],ascending=True)
# Out:
#          rank discipline   phd  service     sex    salary
# 9        Prof          A  51.0       51    Male   57800.0
# 54  AssocProf          A  25.0       22  Female   62884.0
# 66   AsstProf          A   7.0        6  Female   63100.0
# 71  AssocProf          B  12.0        9  Female   71065.0
# 57   AsstProf          A   3.0        1  Female   72500.0
# ..        ...        ...   ...      ...     ...       ...
# 72       Prof          B  24.0       15  Female  161101.0
# 13       Prof          B   NaN       33    Male  162200.0
# 0        Prof          B  56.0       49    Male  186960.0
# 7        Prof          A  18.0       18    Male       NaN
# 28   AsstProf          B   7.0        2    Male       NaN
#
# [78 rows x 6 columns]

# %%
df.sort_values(by=['salary'],ascending=False)
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 13       Prof          B   NaN       33    Male  162200.0
# 72       Prof          B  24.0       15  Female  161101.0
# 27       Prof          A  45.0       43    Male  155865.0
# 31       Prof          B  22.0       21    Male  155750.0
# ..        ...        ...   ...      ...     ...       ...
# 66   AsstProf          A   7.0        6  Female   63100.0
# 54  AssocProf          A  25.0       22  Female   62884.0
# 9        Prof          A  51.0       51    Male   57800.0
# 7        Prof          A  18.0       18    Male       NaN
# 28   AsstProf          B   7.0        2    Male       NaN
#
# [78 rows x 6 columns]

# %%
df.sort_values(by=['salary','phd'],ascending=[True,True])
# Out:
#          rank discipline   phd  service     sex    salary
# 9        Prof          A  51.0       51    Male   57800.0
# 54  AssocProf          A  25.0       22  Female   62884.0
# 66   AsstProf          A   7.0        6  Female   63100.0
# 71  AssocProf          B  12.0        9  Female   71065.0
# 55   AsstProf          A   2.0        0  Female   72500.0
# ..        ...        ...   ...      ...     ...       ...
# 72       Prof          B  24.0       15  Female  161101.0
# 13       Prof          B   NaN       33    Male  162200.0
# 0        Prof          B  56.0       49    Male  186960.0
# 28   AsstProf          B   7.0        2    Male       NaN
# 7        Prof          A  18.0       18    Male       NaN
#
# [78 rows x 6 columns]

# %%
df.sort_values(by=['salary','phd'],ascending=[True,False])
# Out:
#          rank discipline   phd  service     sex    salary
# 9        Prof          A  51.0       51    Male   57800.0
# 54  AssocProf          A  25.0       22  Female   62884.0
# 66   AsstProf          A   7.0        6  Female   63100.0
# 71  AssocProf          B  12.0        9  Female   71065.0
# 57   AsstProf          A   3.0        1  Female   72500.0
# ..        ...        ...   ...      ...     ...       ...
# 72       Prof          B  24.0       15  Female  161101.0
# 13       Prof          B   NaN       33    Male  162200.0
# 0        Prof          B  56.0       49    Male  186960.0
# 7        Prof          A  18.0       18    Male       NaN
# 28   AsstProf          B   7.0        2    Male       NaN
#
# [78 rows x 6 columns]

# %%
d=df.iloc[:,0:3]
d[d.isnull()==False]
# Out:
#          rank discipline   phd
# 0        Prof          B  56.0
# 1        Prof          A  12.0
# 2        Prof          A  23.0
# 3        Prof          A  40.0
# 4        Prof          B  20.0
# ..        ...        ...   ...
# 73       Prof          B  18.0
# 74  AssocProf          B  19.0
# 75       Prof          B  17.0
# 76       Prof          A  28.0
# 77       Prof          A  23.0
#
# [78 rows x 3 columns]

# %%
df[df['salary'].isnull()]
# Out:
#         rank discipline   phd  service   sex  salary
# 7       Prof          A  18.0       18  Male     NaN
# 28  AsstProf          B   7.0        2  Male     NaN

# %%
df[df.isnull().any(axis=1)]                                  # tells which rows has Nan or notb
# Out:
#          rank discipline   phd  service   sex    salary
# 7        Prof          A  18.0       18  Male       NaN
# 13       Prof          B   NaN       33  Male  162200.0
# 28   AsstProf          B   7.0        2  Male       NaN
# 34  AssocProf          B   NaN        8  Male  119800.0

# %%
df.isnull().any(axis=0)
# Out:
# rank          False
# discipline    False
# phd            True
# service       False
# sex           False
# salary         True
# dtype: bool

# %%
df.isnull().any(axis=0).value_counts()
# Out:
# False    4
# True     2
# dtype: int64

# %%
df.isnull().any(axis=1)                                # gives row has NaN or not
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Length: 78, dtype: bool

# %%
df[df['salary'].isnull()]
# Out:
#         rank discipline   phd  service   sex  salary
# 7       Prof          A  18.0       18  Male     NaN
# 28  AsstProf          B   7.0        2  Male     NaN

# %%
df1 = df.copy()
df1['salary'].dropna()
df1
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# ..        ...        ...   ...      ...     ...       ...
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0
#
# [78 rows x 6 columns]

# %%
df[['salary']]
# Out:
#       salary
# 0   186960.0
# 1    93000.0
# 2   110515.0
# 3   131205.0
# 4   104800.0
# ..       ...
# 73  105450.0
# 74  104542.0
# 75  124312.0
# 76  109954.0
# 77  109646.0
#
# [78 rows x 1 columns]

# %%
df1 = df1.fillna(0)
df1[df1['salary']==0]
# Out:
#         rank discipline   phd  service   sex  salary
# 7       Prof          A  18.0       18  Male     0.0
# 28  AsstProf          B   7.0        2  Male     0.0

# %%
df1 = df.fillna(round(df.mean()))
df1
# Out:
#         rank discipline   phd  service   sex    salary
# 7       Prof          A  18.0       18  Male  108003.0
# 28  AsstProf          B   7.0        2  Male  108003.0

# %%
df1[df1['salary']==round(df['salary'].mean())]
# Out:
#         rank discipline   phd  service   sex    salary
# 7       Prof          A  18.0       18  Male  108003.0
# 28  AsstProf          B   7.0        2  Male  108003.0

# %%
df['salary'] = df['salary'].replace('INR','').replace(',','')      # to remove INR and ',' from the salary column 
df['salary']
# Out:
# 0     186960.0
# 1      93000.0
# 2     110515.0
# 3     131205.0
# 4     104800.0
#         ...
# 73    105450.0
# 74    104542.0
# 75    124312.0
# 76    109954.0
# 77    109646.0
# Name: salary, Length: 78, dtype: float64

# %%
df['salary'] = pd.to_numeric(df['salary'])                        # to convert salary in numeric form 
df[['salary']]
# Out:
#       salary
# 0   186960.0
# 1    93000.0
# 2   110515.0
# 3   131205.0
# 4   104800.0
# ..       ...
# 73  105450.0
# 74  104542.0
# 75  124312.0
# 76  109954.0
# 77  109646.0
#
# [78 rows x 1 columns]

# %%
df[['sex']]
# Out:
#        sex
# 0     Male
# 1     Male
# 2     Male
# 3     Male
# 4     Male
# ..     ...
# 73  Female
# 74  Female
# 75  Female
# 76  Female
# 77  Female
#
# [78 rows x 1 columns]

# %%
df['bool_sex']=df['sex'].map(lambda x:0 if x=='Female' else 1)
df
# Out:
#          rank discipline   phd  service     sex    salary  bool_sex
# 0        Prof          B  56.0       49    Male  186960.0         1
# 1        Prof          A  12.0        6    Male   93000.0         1
# 2        Prof          A  23.0       20    Male  110515.0         1
# 3        Prof          A  40.0       31    Male  131205.0         1
# 4        Prof          B  20.0       18    Male  104800.0         1
# ..        ...        ...   ...      ...     ...       ...       ...
# 73       Prof          B  18.0       10  Female  105450.0         0
# 74  AssocProf          B  19.0        6  Female  104542.0         0
# 75       Prof          B  17.0       17  Female  124312.0         0
# 76       Prof          A  28.0       14  Female  109954.0         0
# 77       Prof          A  23.0       15  Female  109646.0         0
#
# [78 rows x 7 columns]

# %% [markdown]
# # Analysis of Tiatnic Data

# %% [markdown]
# ## How many people survived the disaster ?

# %%
import pandas as pd
titanic_data = pd.read_csv(r'C:\Users\Yogi\Downloads\training_titanic.csv')
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
(titanic_data['Survived']==1).value_counts(normalize=True)*100
# Out:
# False    61.616162
# True     38.383838
# Name: Survived, dtype: float64

# %%
a, b=(titanic_data['Survived']==1).value_counts(normalize=True)*100
print('survived -:{}%\nDied -:{}%'.format(round(b),round(a)))
# Out:
# survived -:38%
# Died -:62%

# %%
a,b=((titanic_data['Sex']=='male') & (titanic_data['Survived']==1)).value_counts(normalize=True)*100
print('Male Died',round(a),'%')
print('Male Survived',round(b),'%')
# Out:
# Male Died 88 %
# Male Survived 12 %

# %%
t,s=((titanic_data['Sex']=='female') & (titanic_data['Survived']==True)).value_counts(normalize=True)*100
print('Female Survived :',round(t),'%')
print('Female Died',round(s),'%')
# Out:
# Female Survived : 74 %
# Female Died 26 %

# %%
titanic_data[(titanic_data['Age']<=15) & (titanic_data['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 22            23         1       3
# 39            40         1       3
# 43            44         1       2
# 58            59         1       2
# 78            79         1       2
# 125          126         1       3
# 165          166         1       3
# 172          173         1       3
# 183          184         1       2
# 184          185         1       3
# 193          194         1       2
# 233          234         1       3
# 237          238         1       2
# 261          262         1       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 381          382         1       3
# 407          408         1       2
# 435          436         1       1
# 445          446         1       1
# 446          447         1       2
# 448          449         1       3
# ...

# %%
titanic_data[titanic_data['Age']<=10].count()
# Out:
# PassengerId    64
# Survived       64
# Pclass         64
# Name           64
# Sex            64
# Age            64
# SibSp          64
# Parch          64
# Ticket         64
# Fare           64
# Cabin          10
# Embarked       64
# dtype: int64

# %%
(titanic_data['Age']<=18).value_counts()              # no. of children
# Out:
# False    752
# True     139
# Name: Age, dtype: int64

# %%
((titanic_data['Age']<=18) & (titanic_data['Survived']==1)).value_counts()    # children that survived
# Out:
# False    821
# True      70
# dtype: int64

# %%
titanic_data['Child']=titanic_data['Age'].map(lambda x: 1 if x <= 18 else 0)
titanic_data.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 449          450         1       1      Peuchen, Major. Arthur Godfrey
# 797          798         1       3                    Osman, Mrs. Mara
# 635          636         1       2                   Davis, Miss. Mary
# 245          246         0       1         Minahan, Dr. William Edward
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 813          814         0       3  Andersson, Miss. Ebba Iris Alfrida
# 475          476         0       1         Clifford, Mr. George Quincy
# 58            59         1       2        West, Miss. Constance Mirium
# 7              8         0       3      Palsson, Master. Gosta Leonard
# 740          741         1       1         Hawksford, Mr. Walter James
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Child
# 449    male  52.0      0      0      113786  30.5000  C104        S      0
# ...

# %%
titanic_data['Age'].map(lambda x: 1 if x <= 18 else 0).value_counts()
# Out:
# 0    752
# 1    139
# Name: Age, dtype: int64

# %%
titanic_data['Survived'][(titanic_data['Age']<=18) & (titanic_data['Sex']=='female')].value_counts(normalize=True)*100
# Out:
# 1    67.647059
# 0    32.352941
# Name: Survived, dtype: float64

# %%
df[((df['salary']==df['salary'].max()) | (df['salary']==df['salary'].min()))]
# Out:
#    rank discipline   phd  service   sex    salary
# 0  Prof          B  56.0       49  Male  186960.0
# 9  Prof          A  51.0       51  Male   57800.0

# %%
df1=df[(df['rank']=='Prof') & (df['sex']=='Female')][['salary']]
print(df1['salary'].min(),df1['salary'].max(),sep='\t')
# Out:
# 90450.0	161101.0

# %%
df.groupby(['rank','sex']).min()
# Out:
#                  discipline   phd  service   salary
# rank      sex
# AssocProf Female          A  10.0        6  62884.0
#           Male            A   9.0        7  81285.0
# AsstProf  Female          A   2.0        0  63100.0
#           Male            A   1.0        0  73000.0
# Prof      Female          A  12.0        0  90450.0
#           Male            A  12.0        3  57800.0

# %%
df.groupby(['rank','sex']).max()
# Out:
#                  discipline   phd  service    salary
# rank      sex
# AssocProf Female          B  26.0       24  109650.0
#           Male            B  20.0       17  119800.0
# AsstProf  Female          B  11.0        6   97032.0
#           Male            B   8.0        4   92000.0
# Prof      Female          B  39.0       36  161101.0
#           Male            B  56.0       51  186960.0

# %%
mn=df[(df['rank']=='Prof') & (df['sex']=='Female')][['salary']].min()
print(mn[0])
mx=df[(df['rank']=='Prof') & (df['sex']=='Female')][['salary']].max()
# Out:
# 90450.0

# %%
df[(df['rank']=='Prof') & (df['sex']=='Female') & (df['salary']==mn[0])][['rank','salary']]
# Out:
#     rank   salary
# 67  Prof  90450.0

# %%
df[(df['rank']=='Prof') & (df['sex']=='Female') & (df['salary']==mn[0])]
# Out:
#     rank discipline   phd  service     sex   salary
# 67  Prof          A  17.0       11  Female  90450.0

# %%
df[(df['rank']=='Prof') & (df['sex']=='Female') & (df['salary']==mx[0])]
# Out:
#     rank discipline   phd  service     sex    salary
# 72  Prof          B  24.0       15  Female  161101.0

# %%
 '''
         Which Male and Female Professor has the highest and the lowest salaries.
         
 '''  
fmn=df[(df['rank']=='Prof') & (df['sex']=='Female')][['salary']].min()
fmx=df[(df['rank']=='Prof') & (df['sex']=='Female')][['salary']].max()  
mmn=df[(df['rank']=='Prof') & (df['sex']=='Male')][['salary']].min()
mmx=df[(df['rank']=='Prof') & (df['sex']=='Male')][['salary']].max()
df[(df['rank']=='Prof') & (df['sex']=='Female') & ((df['salary']==fmn[0]) | (df['salary']==fmx[0]))]
# Out:
#     rank discipline   phd  service     sex    salary
# 67  Prof          A  17.0       11  Female   90450.0
# 72  Prof          B  24.0       15  Female  161101.0

# %%
df[(df['rank']=='Prof') & (df['sex']=='Male') & ((df['salary']==mmn[0]) | (df['salary']==mmx[0]))]
# Out:
#    rank discipline   phd  service   sex    salary
# 0  Prof          B  56.0       49  Male  186960.0
# 9  Prof          A  51.0       51  Male   57800.0

# %%
'''      
         Which Professor takes the highest and lowest salaries
         
'''
mn=df[(df['rank']=='Prof')][['salary']].min()
mx=df[(df['rank']=='Prof')][['salary']].max()
df[(df['rank']=='Prof')  & ((df['salary']==mn[0]) | (df['salary']==mx[0]))]
# Out:
#    rank discipline   phd  service   sex    salary
# 0  Prof          B  56.0       49  Male  186960.0
# 9  Prof          A  51.0       51  Male   57800.0

# %%
'''


      Missing Salaries - should be mean of the matching salaries of those whose service is the same
      
'''
df['salary']=df['salary'].fillna(df['salary'].mean())
df[['salary']]
# Out:
#       salary
# 0   186960.0
# 1    93000.0
# 2   110515.0
# 3   131205.0
# 4   104800.0
# ..       ...
# 73  105450.0
# 74  104542.0
# 75  124312.0
# 76  109954.0
# 77  109646.0
#
# [78 rows x 1 columns]

# %%
'''

     Missing phd - should be mean of the matching service 

'''

df['phd']=df['phd'].fillna(round(df['phd'].mean(),1))
df[['phd']]
# Out:
#      phd
# 0   56.0
# 1   12.0
# 2   23.0
# 3   40.0
# 4   20.0
# ..   ...
# 73  18.0
# 74  19.0
# 75  17.0
# 76  28.0
# 77  23.0
#
# [78 rows x 1 columns]

# %%
df['sex'].value_counts(normalize=True)*100
# Out:
# Female    50.0
# Male      50.0
# Name: sex, dtype: float64

# %%
plt.pie(df['sex'].value_counts(),labels=['male','female'],colors=['r','g'],startangle=90,shadow=True,explode=(0.1,0),autopct='%1.1f%%')
plt.title('Male count V/s Female count\n')
plt.show()

# %%
'''
            How many are Prof, AssocProf and AsstProf. 
            Show both in numbers adn Graphically using a Pie Chart       
       
'''

plt.pie(df['rank'].value_counts(),labels=['Prof','Assntprof','Assotprof'],colors=['r','g','b'],startangle=90,shadow=True,explode=(0.1,0,0),autopct=lambda p: '{:.0f}'.format(p * 78 / 100))
plt.title('Male count V/s Female count\n')
plt.show()
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
'''
      Who are the senior and junior most employees in the organization
      
'''  
df[(df['service']==df['service'].min())]
# Out:
#         rank discipline   phd  service     sex    salary
# 12  AsstProf          B   1.0        0    Male   88000.0
# 17  AsstProf          B   4.0        0    Male   92000.0
# 23  AsstProf          A   2.0        0    Male   85000.0
# 43  AsstProf          B   5.0        0  Female   77000.0
# 52      Prof          A  12.0        0  Female  105000.0
# 55  AsstProf          A   2.0        0  Female   72500.0

# %%
df[(df['service']==df['service'].max())]
# Out:
#    rank discipline   phd  service   sex   salary
# 9  Prof          A  51.0       51  Male  57800.0

# %%
bins=range(50000, 200000 + 15000, 15000)
plt.figure(figsize=(12,4))
plt.hist(x=df['salary'].map(lambda x:int(x)),label='salary vs count',color='g',bins=bins)
plt.ylabel('y axis')
plt.legend()
# plt.xlabel('x axis')
plt.title('Histogram')
plt.grid(color='r')
plt.xticks(range(50000, 200000, 15000),rotation=45)
plt.yticks(range(0,20,2),rotation=45)
plt.show()

# %%
z=[i for i in df.groupby(['rank','sex']).count()
z
# Out:
# [10, 3, 11, 8, 18, 28]

# %%
x=list(df['rank'].unique())
x=x*2
x
# Out:
# ['Prof', 'AssocProf', 'AsstProf', 'Prof', 'AssocProf', 'AsstProf']

# %%
y=[]
str1=list(df['sex'].unique())[0]
str2=list(df['sex'].unique())[1]
for i in range(3):
    y.append(str1)
for i in range(3):
    y.append(str2)    
y
# Out:
# ['Male', 'Male', 'Male', 'Female', 'Female', 'Female']

# %%
df1=pd.DataFrame(zip(x,y,z),columns=['rank','sex','count'])
df1
# Out:
#         rank     sex  count
# 0       Prof    Male     10
# 1  AssocProf    Male      3
# 2   AsstProf    Male     11
# 3       Prof  Female      8
# 4  AssocProf  Female     18
# 5   AsstProf  Female     28

# %%
plt.figure(figsize=(12,3))
sns.heatmap(df1.pivot('rank','sex','count'),annot=True,linewidth=0.5,cmap='Blues')
plt.title('HeatMap')
# Out:
# Text(0.5, 1, 'HeatMap')

# %%
'''
       
        How can I apply arithmetic operation between two rows of an Excel file and print the result in that Excel
        file itself in the next row using Python 3? eg: in the second row and first column the data is given as 
        2 then next column 3 and followed by 4 and 5. Similarly in the next row the data is given in same manner 
        as 6,7,8 and 9. We have to add respective data in specific manner is 2+6, 3+7, 4+8 and 5+9. Print the result
        in the next row in excel file.


'''
import pandas as pd
df=pd.read_excel(r'C:\Users\Yogi\Desktop\Book1.xlsx')               # the path where your xlsl file is
rows=df.shape[0]
column=df.shape[1]
a,b,c,d=list(df['a']),list(df['b']),list(df['c']),list(df['d'])     # a, b, c, d are the columns name of xlsl file
df1=pd.DataFrame(columns=['a','b','c','d'])
df2=pd.DataFrame(columns=['a','b','c','d'])
r1=j=0
for i in range(rows//2):  
    df1.loc[j]=[sum(a[r1:r1+2]),sum(b[r1:r1+2]),sum(c[r1:r1+2]),sum(d[r1:r1+2])]
    r1+=2
    j+=1
j=k=l=0
while(k<rows//2):
    df2.loc[l]=df.loc[j]
    df2.loc[l+1]=df.loc[j+1]
    df2.loc[l+2]=df1.loc[k]
    l+=3
    j+=2
    k+=1   
df2.to_excel("output.xlsx")                           # output.xlsl is your desired file
