# %%
print('Welcome to Matplotlib')
# Out:
# Welcome to Matplotlib

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

# %%
x=np.arange(0,50)
y=np.sin(x)
style.use('ggplot',)
plt.plot(x,y ,color='g',label='Sin(x)')
plt.xlabel('X asix')
plt.ylabel('Y axis')
plt.title('Sin(x)',fontdict={'fontname':'DejaVu Sans','fontsize':30})
plt.grid(True,color="b")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style
style.use('ggplot')
x=np.arange(0,50)
z=np.cos(x)
plt.plot(x,z,color='r',label='Cos(x)',marker='*',markersize=10,markeredgecolor='b')
plt.xlabel('X asix')
plt.ylabel('Y axis')
plt.xticks([0,10,20,30,40,50])
plt.yticks([-1,0,1])
plt.title('Cos(x)',fontdict={'fontname':'DejaVu Sans','fontsize':30})
plt.grid(color="g")
plt.legend()
plt.show()

# %%
x = [1, 2, 3, 4, 5, 6]
y = [4, 5, 6, 3, 2, 1]
z = [7, 8, 9, 2, 3, 5]
style.use("ggplot")
plt.plot(x,y,"g",label = 'x,y line',linewidth=5)
plt.plot(x,z,"r",label = "x,z line",linewidth=5)
plt.title("Line graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend()
plt.grid(True,color='k')
plt.show()

# %%
y = [4, 9, 6, 3, 2, 1]
z = [7, 8, 9, 2, 3, 5]
style.use('ggplot')
plt.bar(x,y,color='r',label='x,y Bar',width=0.8)
plt.bar(x,z,color= 'g',label='x,z Bar',width=0.5)
plt.title('Bar garph')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.grid(color='k')
plt.legend()
plt.show()

# %%
x = [5,207,206,208,203,244,122,344,252,466,500,703,705801,802,803,805,806,703,706,790,723,800,802,801,903,933,956]
y = [0, 100,200,300,400,500,600,700,800,900,1000]
plt.hist(x,y,color='g',label='stdnt vs money',rwidth=1)
plt.legend()
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Histogram')
plt.grid(color='k')
plt.show()

# %%
x = [1, 2, 3, 4, 5, 6]
y = [4, 9, 6, 3, 2, 1]
z = [7, 8, 9, 2, 3, 5]
style.use('ggplot')
plt.scatter(x,y,label='--> x,y scatter',color='r')
plt.scatter(y,z,label='--> y,z scatter',color='g')
plt.scatter(x,z,label='--> x,z scatter', color='b')
plt.legend()
plt.grid(color='k')
plt.title('Scatter Graph')
plt.xlabel('x axis',color='b')
plt.ylabel('y axis',color='b')
plt.show()

# %%
days=[1, 2, 3, 4, 5]

sleeping=[7, 8, 6, 11, 7]
eating = [2, 3, 4, 3, 2]
working= [7, 8, 7, 2, 2]
playing= [8,5, 7,8,13]
style.use('ggplot')
plt.plot([],[],color='m',label='sleeping')
plt.plot([],[],color='g',label='eating')
plt.plot([],[],color='r',label='working')
plt.plot([],[],color='b',label='playing')
plt.legend()


plt.stackplot(days,sleeping,eating,working,playing,colors=['m','g','r','b'])
plt.xlabel('Hour',color='b')
plt.ylabel('no. of employees',color='b')
plt.title('Stackplot')
plt.grid(color='k')
plt.show()

# %%
x=[7, 2, 2, 13]
activities=['sleeping','eating','working','playing']
plt.pie(x,labels=activities,colors=['m','c','r','g'],startangle=90,shadow=True,explode=(0.1,0,0,0),autopct=('%1.1f%%'))
plt.legend()
plt.title('Pie Chart')
autopct=()
plt.show()

# %%
def f(t) :
    return np.exp(-t)*np.cos(2*np.pi*t)
t1=np.arange(0.0,5.0,0.1)
t2=np.arange(0.0,5.0,0.02)

plt.subplot(121)
plt.plot(t1,f(t1),'ro',t2,f(t2))
plt.grid(color='k')
plt.title('Plot 1')
plt.xlabel('x axis',color='b')
plt.ylabel('y axis',color='b')
plt.subplot(122)
plt.plot(t2,f(t2),'bo')
plt.grid(color='k')
plt.title(' Plot 2')
plt.xlabel('x axis',color='b')
# plt.ylabel('y axis',color='b')
plt.show()

# %%
plt.figure(figsize=(30,10))
x=['v','i','b','g','y','o','r']
y=[6,6,6,6,6,6,6]
plt.bar(x,list(map(lambda x:x**2,y)),color=['violet','indigo','blue','green','yellow','orange','red'],label=['Railbow Bar Graph'],width=1)
plt.yticks(np.arange(0,40,4),rotation=30)
plt.xticks(['v','i','b','g','y','o','r'],rotation=45)
plt.legend()
plt.grid(False)
plt.show()

# %%
# plt.pie([1],colors=['b'],radius=0.3)
# plt.show()
plt.barh(['a','b','c'],[3,3,3],color=['g','w','r'],alpha=0.5)
plt.grid(False)
plt.show()

# %%
import numpy
from matplotlib import pyplot, transforms

data = numpy.random.randn(100)

# first of all, the base transformation of the data points is needed
base = pyplot.gca().transData
rot = transforms.Affine2D().rotate_deg(90)

# define transformed line
line = pyplot.plot(data, 'r--', transform= rot + base)
# or alternatively, use:
# line.set_transform(rot + base)

pyplot.show()
