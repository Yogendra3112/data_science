# %%
print('Welcome to Matplotlib')
# Out:
# Welcome to Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arange(0,100)
y=np.sin(np.array(x))

plt.plot(x,y ,color='b',label='Sin(x)')
plt.xlabel('X asix')
plt.ylabel('Y axis')
plt.title('Line Graph',fontdict={'fontname':'DejaVu Sans','fontsize':30})
plt.grid(color="b")
plt.legend()
plt.show()
